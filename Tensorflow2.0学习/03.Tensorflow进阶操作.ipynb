# %% [markdown]
# # Tensorflow 进阶知识
# ---
# 拼接
# - stack
# 分割
# - unstack
# - split 高级
#
#
# 数据统计
# - reduce_max
# - reduce_sum
# - argmax
# - unique
# - norm
#
#
# 数据填充（适用于卷积网络的填充）
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
#
#
# tile函数
# ![image.png](attachment:image.png)

# %%
import tensorflow as tf

# %%
a = tf.constant(tf.random.normal([3,2]))
a

# %%
tf.argmax(a,axis = 0) # shape = 3,2  第0个表示列

# %%
tf.reduce_max(a,axis = 0) # shape = 3,2  第0个表示列

# %% [markdown]
# ### 其他常见tensorflow函数
#
# - tf.where 返回下标
#    - 单个参数 （tf.bool的矩阵）,返回其下标
#    - 三个参数
#
# - tf.gether_nd
