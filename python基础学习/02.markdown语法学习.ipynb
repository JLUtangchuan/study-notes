# %% [markdown]
# # Markdown语法学习

# %% [markdown]
# 优缺点
# ![image.png](attachment:image.png)

# %% [markdown]
# # 这是一级标题
# ## 这是二级标题
# ### 这是三级标题
# #### 这是四级标题
# ##### 这是五级标题
# ###### 这是六级标题
#
# 注意： #后面记得加空格！！！

# %% [markdown]
# # 字体
# ![image.png](attachment:image.png)
#
#
# **这是加粗的文字**
# *这是倾斜的文字*
# ***这是斜体加粗的文字***
# ~~这是加删除线的文字~~

# %% [markdown]
# # 引用
# hello world
# > “你好”
# >
# 结束时在加入一个大于号

# %% [markdown]
# # 分割线
# 三个“-” or “*”
#
# ---
# ***

# %% [markdown]
# # 图片
#
#
# “![图片下方文字]()”

# %% [markdown]
# # 超链接
# >[baidu](https://www.baidu.com)
#
# >[google](http://www.googel.com)

# %% [markdown]
# # 列表
#
# ![image.png](attachment:image.png)

# %% [markdown]
# - 首先
# - 其次
# - 最后

# %% [markdown]
# 1. 首先
# 2. 而后
# 3. 最终
#
# 注意空格！！

# %%
# %%markdown
# #### 嵌套列表
# - 11111
#    - 222
#    - 223
# - 333
#
# 加入三个空格
# Out:
# #### 嵌套列表
# - 11111
#    - 222
#    - 223
# - 333
#
# 加入三个空格

# %% [markdown]
# # 表格
#
# 表头|表头|表头
# ---|:--:|---:
# 内容|内容|内容
# 内容|内容|内容
#
# 第二行分割表头和内容。
# - 有一个就行，为了对齐，多加了几个
# 文字默认居左
# - 两边加：表示文字居中
# - 右边加：表示文字居右
#     注：
#     1. 原生的语法两边都要用 | 包起来。此处省略
#     2. 横线占位 多少无所谓
#
# ## 居中
#     两边加冒号（居左就在左边加冒号）

# %% [markdown]
# 班级|姓名|学号
# ----|:---:|---
# 1|tc|2019001

# %% [markdown]
# 姓名|技能|排行
# --|:--:|--:
# 刘备|哭|大哥
# 关羽|打|二哥
# 张飞|骂|三弟

# %% [markdown]
# # 代码
#
# 使用反引号
# 1. 单行代码 单个反引号
# 2. 多行代码 多个反引号
#
#
# #### 单行代码
#  `
#      print('hello world')
#  `
#
# #### 多行代码
# ```
#     import tensorflow as tf
#     import sys
#
# ```

# %% [markdown]
# 此外，md还支持流程图（不学了！！！）

# %% [markdown]
# $$L(x)=x^{T}A^{2}x-u(x^{T}x-1) $$
