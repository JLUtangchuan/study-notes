# %% [markdown]
# # RNN Cell Tensorflow实现

# %%
import tensorflow as tf
from tensorflow.keras import layers,optimizers,metrics,Sequential,datasets

# %%
# layers.SimpleRNNCell

# %%
rnn = layers.SimpleRNNCell()

# %%
# 调用

# out,x1=rnn(x0,h0)
x0 = tf.random.normal([20,100])
h0 = tf.zeros([20,64])
out,h1 = rnn(x0,[h0])

# %%
out.shape
# Out:
# TensorShape([20, 64])

# %% [markdown]
# ###  multi-layer RNN
# $h_{0}^{1} ,h_{1}^{1},h_{2}^{1},h_{3}^{1},... $
#
# $h_{0}^{2},h_{1}^{2},h_{2}^{2},h_{3}^{2},...$
#
# ![image.png](attachment:image.png)

# %% [markdown]
# SimpleRNN
